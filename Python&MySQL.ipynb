# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_profiling as pp
import seaborn

# %%
import sys
import os
sys.executable
# Out:
# 'c:\\python37\\python.exe'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('8zLQLUpNGsc')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json

# some JSON:
x =  '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
x = {"Name":['John', "Isaac", "Allan"], "Age": [23, 34, 56], "City": ["New York", "California", "Berlin"]}

# %%
df = pd.DataFrame(x)

# %%
df
# Out:
#     Name  Age        City
# 0   John   23    New York
# 1  Isaac   34  California
# 2  Allan   56      Berlin

# %%
def classify_age(age):
    if age > 25:
        return "Out of school"
    else:
        return "still looking"

# %%
df['status'] = df['Age'].apply(classify_age)

# %%
df
# Out:
#     Name  Age        City         status
# 0   John   23    New York  still looking
# 1  Isaac   34  California  Out of school
# 2  Allan   56      Berlin  Out of school

# %%
pp.ProfileReport(df)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-10-24 15:15:50.631157&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

print(json.dumps(x))
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  password="kabzi80"
)

print(mydb)

# %%
mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE kabzimula")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="kabzi80",
  database="kabzimula"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
# load pandas and json modules                                                                                               
import pandas as pd
import json

# json string                                                                                                                
s = '{"col1":{"row1":1,"row2":2,"row3":3},"col2":{"row1":"x","row2":"y","row3":"z"}}'

# read json to data frame                                                                                                    
df = pd.read_json(s)
print(df)
# Out:
#       col1 col2
# row1     1    x
# row2     2    y
# row3     3    z

# %%
import requests
from pandas.io.json import json_normalize
import pandas as pd

url = "https://api.exchangerate-api.com/v4/latest/USD"
df = pd.read_json(url)
print(df)
# Out:
#     base       date  time_last_updated         rates
# AED  USD 2020-10-24         1603497845      3.672039
# ARS  USD 2020-10-24         1603497845     78.062937
# AUD  USD 2020-10-24         1603497845      1.400761
# BGN  USD 2020-10-24         1603497845      1.650470
# BRL  USD 2020-10-24         1603497845      5.584766
# BSD  USD 2020-10-24         1603497845      1.000000
# CAD  USD 2020-10-24         1603497845      1.312889
# CHF  USD 2020-10-24         1603497845      0.904653
# CLP  USD 2020-10-24         1603497845    779.987998
# CNY  USD 2020-10-24         1603497845      6.675226
# COP  USD 2020-10-24         1603497845   3721.000000
# CZK  USD 2020-10-24         1603497845     22.963404
# DKK  USD 2020-10-24         1603497845      6.281849
# DOP  USD 2020-10-24         1603497845     58.140625
# EGP  USD 2020-10-24         1603497845     15.697268
# EUR  USD 2020-10-24         1603497845      0.844112
# FJD  USD 2020-10-24         1603497845      2.132204
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AED to ZAR
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   base               52 non-null     object
#  1   date               52 non-null     datetime64[ns]
#  2   time_last_updated  52 non-null     int64
#  3   rates              52 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df.isnull().sum()
# Out:
# base                 0
# date                 0
# time_last_updated    0
# rates                0
# dtype: int64

# %%
df.shape
# Out:
# (52, 4)

# %%
df['rates'].max()
# Out:
# 14830.968371

# %%
df[df['rates'] == df['rates'].max()]
# Out:
#     base       date  time_last_updated         rates
# IDR  USD 2020-10-24         1603497845  14830.968371

# %%
df[df['rates'] == df['rates'].min()]
# Out:
#     base       date  time_last_updated     rates
# GBP  USD 2020-10-24         1603497845  0.765161

# %%
df['rates'].nlargest(5).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['rates'].nsmallest(5).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['rates'].mean()
# Out:
# 564.7852879807692

# %%
df['rates'].median()
# Out:
# 8.356687

# %%
df['rates'].std()
# Out:
# 2300.5816578916238

# %%
df['rates'].var()
# Out:
# 5292675.964627373

# %%
df['rates'].max()
# Out:
# 14830.968371

# %%
df['rates'].min()
# Out:
# 0.765161
